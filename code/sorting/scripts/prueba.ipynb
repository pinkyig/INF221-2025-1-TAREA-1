# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/measurements/time.txt')

df.head()

# %%
# Filtrar los datos de tipo 'aleatorio'
df_aleatorio = df[df['type'] == 'aleatorio']

# Graficar el tamaño de la entrada con respecto al tiempo para cada algoritmo
plt.figure(figsize=(10, 6))
plt.plot(df_aleatorio['size'], df_aleatorio['MergeSort_microseg'], label='MergeSort')
plt.plot(df_aleatorio['size'], df_aleatorio['QuickSort_microseg'], label='QuickSort')
plt.plot(df_aleatorio['size'], df_aleatorio['SelectionSort_microseg'], label='SelectionSort')
plt.plot(df_aleatorio['size'], df_aleatorio['LibrarySort_microseg'], label='LibrarySort')

# Configurar etiquetas y título
plt.xlabel('Tamaño de la entrada')
plt.ylabel('Tiempo (microsegundos)')
plt.title('Tamaño de la entrada vs Tiempo para datos aleatorios')
plt.legend()
plt.grid(True)
plt.xscale('log')  # Escala logarítmica para el eje x
plt.yscale('log')  # Escala logarítmica para el eje y
plt.show()


# Calcular el promedio de tiempo de ejecución para cada tamaño en los datos aleatorios
promedios_aleatorios = df_aleatorio.groupby('size')[['MergeSort_microseg', 'QuickSort_microseg', 'SelectionSort_microseg', 'LibrarySort_microseg']].mean()
promedios_aleatorios_ms = promedios_aleatorios / 1000
# Mostrar los promedios
print(promedios_aleatorios_ms)
# Out:
#           MergeSort_microseg  QuickSort_microseg  SelectionSort_microseg  \
# size
# 10                  0.002000            0.000000                0.000000
# 1000                0.156000            0.052833                2.000500
# 100000              8.173667            3.499667             9498.136667
# 10000000          987.143167          461.441333               -0.001000
#
#           LibrarySort_microseg
# size
# 10                    0.000000
# 1000                  0.066167
# 100000                2.807667
# 10000000            364.102500

# %%
# Filtrar los datos de tipo 'ascendente'
df_ascendente = df[df['type'] == 'ascendente']

# Graficar el tamaño de la entrada con respecto al tiempo para cada algoritmo
plt.figure(figsize=(10, 6))
plt.plot(df_ascendente['size'], df_ascendente['MergeSort_microseg'], label='MergeSort')
plt.plot(df_ascendente['size'], df_ascendente['QuickSort_microseg'], label='QuickSort')
plt.plot(df_ascendente['size'], df_ascendente['SelectionSort_microseg'], label='SelectionSort')
plt.plot(df_ascendente['size'], df_ascendente['LibrarySort_microseg'], label='LibrarySort')

# Configurar etiquetas y título
plt.xlabel('Tamaño de la entrada')
plt.ylabel('Tiempo (microsegundos)')
plt.title('Tamaño de la entrada vs Tiempo para datos ascendentes')
plt.legend()
plt.grid(True)
plt.xscale('log')  # Escala logarítmica para el eje x
plt.yscale('log')  # Escala logarítmica para el eje y
plt.show()

# Calcular el promedio de tiempo de ejecución para cada tamaño en los datos ascendentes
promedios_ascendentes = df_ascendente.groupby('size')[['MergeSort_microseg', 'QuickSort_microseg', 'SelectionSort_microseg', 'LibrarySort_microseg']].mean()
promedios_ascendentes_ms = promedios_ascendentes / 1000
# Mostrar los promedios
print(promedios_ascendentes_ms)
# Out:
#           MergeSort_microseg  QuickSort_microseg  SelectionSort_microseg  \
# size
# 10                  0.001500            0.000000                  0.0000
# 1000                0.105333            0.012833                  1.9600
# 100000              5.692333            0.942500               9432.6915
# 10000000          722.113500          153.232500                 -0.0010
#
#           LibrarySort_microseg
# size
# 10                    0.000000
# 1000                  0.006833
# 100000                0.212167
# 10000000             18.039000

# %%
# Filtrar los datos de tipo 'descendente'
df_descendente = df[df['type'] == 'descendente']

# Graficar el tamaño de la entrada con respecto al tiempo para cada algoritmo
plt.figure(figsize=(10, 6))
plt.plot(df_descendente['size'], df_descendente['MergeSort_microseg'], label='MergeSort')
plt.plot(df_descendente['size'], df_descendente['QuickSort_microseg'], label='QuickSort')
plt.plot(df_descendente['size'], df_descendente['SelectionSort_microseg'], label='SelectionSort')
plt.plot(df_descendente['size'], df_descendente['LibrarySort_microseg'], label='LibrarySort')

# Configurar etiquetas y título
plt.xlabel('Tamaño de la entrada')
plt.ylabel('Tiempo (microsegundos)')
plt.title('Tamaño de la entrada vs Tiempo para datos descendentes')
plt.legend()
plt.grid(True)
plt.xscale('log')  # Escala logarítmica para el eje x
plt.yscale('log')  # Escala logarítmica para el eje y


# Calcular el promedio de tiempo de ejecución para cada tamaño en los datos descendentes
promedios_descendentes = df_descendente.groupby('size')[['MergeSort_microseg', 'QuickSort_microseg', 'SelectionSort_microseg', 'LibrarySort_microseg']].mean()
promedios_descendentes_ms = promedios_descendentes / 1000
# Mostrar los promedios
print(promedios_descendentes_ms)
# Out:
#           MergeSort_microseg  QuickSort_microseg  SelectionSort_microseg  \
# size
# 10                  0.001667            0.000167                0.000000
# 1000                0.091833            0.009333                1.621667
# 100000              5.807000            0.924667             9422.474000
# 10000000          746.035667          142.384667               -0.001000
#
#           LibrarySort_microseg
# size
# 10                    0.000000
# 1000                  0.008000
# 100000                0.188167
# 10000000             18.663333
